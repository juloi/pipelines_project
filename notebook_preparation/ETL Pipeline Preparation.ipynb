# %% [markdown]
# # ETL Pipeline Preparation
# Follow the instructions below to help you create your ETL pipeline.
# ### 1. Import libraries and load datasets.
# - Import Python libraries
# - Load `messages.csv` into a dataframe and inspect the first few lines.
# - Load `categories.csv` into a dataframe and inspect the first few lines.

# %%
# import libraries
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
# load messages dataset
messages = pd.read_csv('messages.csv', index_col='id')
messages.head()
# Out:
#                                               message  \
# id
# 2   Weather update - a cold front from Cuba that c...
# 7             Is the Hurricane over or is it not over
# 8                     Looking for someone but no name
# 9   UN reports Leogane 80-90 destroyed. Only Hospi...
# 12  says: west side of Haiti, rest of the country ...
#
#                                              original   genre
# id
# 2   Un front froid se retrouve sur Cuba ce matin. ...  direct
# 7                  Cyclone nan fini osinon li pa fini  direct
# 8   Patnm, di Maryani relem pou li banm nouvel li ...  direct
# 9   UN reports Leogane 80-90 destroyed. Only Hospi...  direct
# 12  facade ouest d Haiti et le reste du pays aujou...  direct

# %%
messages.isnull().sum()
# Out:
# message         0
# original    16064
# genre           0
# dtype: int64

# %%
messages[messages['original'].isnull()]
# Out:
#                                                  message original   genre
# id
# 8365            NOTES: It mark as not enough information      NaN  direct
# 11186  My thoughts and prayers go out to all the live...      NaN  social
# 11188  I m sorry for the poor people in Haiti tonight...      NaN  social
# 11189  RT selenagomez UNICEF has just announced an em...      NaN  social
# 11192  lilithia yes 5.2 magnitude earthquake hit mani...      NaN  social
# ...                                                  ...      ...     ...
# 30261  The training demonstrated how to enhance micro...      NaN    news
# 30262  A suitable candidate has been selected and OCH...      NaN    news
# 30263  Proshika, operating in Cox's Bazar municipalit...      NaN    news
# 30264  Some 2,000 women protesting against the conduc...      NaN    news
# 30265  A radical shift in thinking came about as a re...      NaN    news
#
# [16064 rows x 3 columns]

# %%
# load categories dataset
categories = pd.read_csv('categories.csv', index_col='id')
categories.head()
# Out:
#                                            categories
# id
# 2   related-1;request-0;offer-0;aid_related-0;medi...
# 7   related-1;request-0;offer-0;aid_related-1;medi...
# 8   related-1;request-0;offer-0;aid_related-0;medi...
# 9   related-1;request-1;offer-0;aid_related-1;medi...
# 12  related-1;request-0;offer-0;aid_related-0;medi...

# %%
columns = categories['categories'].str.split(';', expand=True).iloc[0].str.split("-", expand=True)[0].to_list()
columns
# Out:
# ['related',
#  'request',
#  'offer',
#  'aid_related',
#  'medical_help',
#  'medical_products',
#  'search_and_rescue',
#  'security',
#  'military',
#  'child_alone',
#  'water',
#  'food',
#  'shelter',
#  'clothing',
#  'money',
#  'missing_people',
#  'refugees',
#  'death',
#  'other_aid',
#  'infrastructure_related',
#  'transport',
#  'buildings',
#  'electricity',
#  'tools',
#  'hospitals',
#  'shops',
#  'aid_centers',
#  'other_infrastructure',
#  'weather_related',
#  'floods',
#  'storm',
#  'fire',
#  'earthquake',
#  'cold',
#  'other_weather',
#  'direct_report']

# %%
categories = categories['categories'].str.split(';', expand=True)
categories.columns = columns
categories.tail()
# Out:
#          related    request    offer    aid_related    medical_help  \
# id
# 30261  related-0  request-0  offer-0  aid_related-0  medical_help-0
# 30262  related-0  request-0  offer-0  aid_related-0  medical_help-0
# 30263  related-1  request-0  offer-0  aid_related-0  medical_help-0
# 30264  related-1  request-0  offer-0  aid_related-1  medical_help-0
# 30265  related-1  request-0  offer-0  aid_related-0  medical_help-0
#
#          medical_products    search_and_rescue    security    military  \
# id
# 30261  medical_products-0  search_and_rescue-0  security-0  military-0
# 30262  medical_products-0  search_and_rescue-0  security-0  military-0
# 30263  medical_products-0  search_and_rescue-0  security-0  military-0
# 30264  medical_products-0  search_and_rescue-0  security-0  military-1
# 30265  medical_products-0  search_and_rescue-0  security-0  military-0
#
#          child_alone  ...    aid_centers    other_infrastructure  \
# id                    ...
# 30261  child_alone-0  ...  aid_centers-0  other_infrastructure-0
# 30262  child_alone-0  ...  aid_centers-0  other_infrastructure-0
# 30263  child_alone-0  ...  aid_centers-0  other_infrastructure-0
# 30264  child_alone-0  ...  aid_centers-0  other_infrastructure-0
# 30265  child_alone-0  ...  aid_centers-0  other_infrastructure-0
#
#          weather_related    floods    storm    fire    earthquake    cold  \
# id
# 30261  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30262  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30263  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30264  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
# 30265  weather_related-0  floods-0  storm-0  fire-0  earthquake-0  cold-0
#
#          other_weather    direct_report
# id
# 30261  other_weather-0  direct_report-0
# 30262  other_weather-0  direct_report-0
# 30263  other_weather-0  direct_report-0
# 30264  other_weather-0  direct_report-0
# 30265  other_weather-0  direct_report-0
#
# [5 rows x 36 columns]

# %%
for col in columns:
    categories[col] = categories[col].str.replace(col + '-', repl='').astype(int)
    
categories.tail()
# Out:
#        related  request  offer  aid_related  medical_help  medical_products  \
# id
# 30261        0        0      0            0             0                 0
# 30262        0        0      0            0             0                 0
# 30263        1        0      0            0             0                 0
# 30264        1        0      0            1             0                 0
# 30265        1        0      0            0             0                 0
#
#        search_and_rescue  security  military  child_alone  ...  aid_centers  \
# id                                                         ...
# 30261                  0         0         0            0  ...            0
# 30262                  0         0         0            0  ...            0
# 30263                  0         0         0            0  ...            0
# 30264                  0         0         1            0  ...            0
# 30265                  0         0         0            0  ...            0
#
#        other_infrastructure  weather_related  floods  storm  fire  earthquake  \
# id
# 30261                     0                0       0      0     0           0
# 30262                     0                0       0      0     0           0
# 30263                     0                0       0      0     0           0
# 30264                     0                0       0      0     0           0
# 30265                     0                0       0      0     0           0
#
#        cold  other_weather  direct_report
# id
# 30261     0              0              0
# 30262     0              0              0
# 30263     0              0              0
# 30264     0              0              0
# 30265     0              0              0
#
# [5 rows x 36 columns]

# %%
categories.isnull().sum()
# Out:
# related                   0
# request                   0
# offer                     0
# aid_related               0
# medical_help              0
# medical_products          0
# search_and_rescue         0
# security                  0
# military                  0
# child_alone               0
# water                     0
# food                      0
# shelter                   0
# clothing                  0
# money                     0
# missing_people            0
# refugees                  0
# death                     0
# other_aid                 0
# infrastructure_related    0
# transport                 0
# buildings                 0
# electricity               0
# tools                     0
# hospitals                 0
# shops                     0
# aid_centers               0
# other_infrastructure      0
# weather_related           0
# floods                    0
# storm                     0
# fire                      0
# earthquake                0
# cold                      0
# other_weather             0
# direct_report             0
# dtype: int64

# %% [markdown]
# ### 2. Merge datasets.
# - Merge the messages and categories datasets using the common id
# - Assign this combined dataset to `df`, which will be cleaned in the following steps

# %%
categories.shape[0] == messages.shape[0]
# Out:
# True

# %%
# merge datasets
df = messages.merge(categories, how='inner', left_index=True, right_index=True)
df.head()
# Out:
#                                               message  \
# id
# 2   Weather update - a cold front from Cuba that c...
# 7             Is the Hurricane over or is it not over
# 8                     Looking for someone but no name
# 9   UN reports Leogane 80-90 destroyed. Only Hospi...
# 12  says: west side of Haiti, rest of the country ...
#
#                                              original   genre  related  \
# id
# 2   Un front froid se retrouve sur Cuba ce matin. ...  direct        1
# 7                  Cyclone nan fini osinon li pa fini  direct        1
# 8   Patnm, di Maryani relem pou li banm nouvel li ...  direct        1
# 9   UN reports Leogane 80-90 destroyed. Only Hospi...  direct        1
# 12  facade ouest d Haiti et le reste du pays aujou...  direct        1
#
#     request  offer  aid_related  medical_help  medical_products  \
# id
# 2         0      0            0             0                 0
# 7         0      0            1             0                 0
# 8         0      0            0             0                 0
# 9         1      0            1             0                 1
# 12        0      0            0             0                 0
#
#     search_and_rescue  ...  aid_centers  other_infrastructure  \
# id                     ...
# 2                   0  ...            0                     0
# 7                   0  ...            0                     0
# 8                   0  ...            0                     0
# 9                   0  ...            0                     0
# 12                  0  ...            0                     0
#
#     weather_related  floods  storm  fire  earthquake  cold  other_weather  \
# id
# 2                 0       0      0     0           0     0              0
# 7                 1       0      1     0           0     0              0
# 8                 0       0      0     0           0     0              0
# 9                 0       0      0     0           0     0              0
# 12                0       0      0     0           0     0              0
#
#     direct_report
# id
# 2               0
# 7               0
# 8               0
# 9               0
# 12              0
#
# [5 rows x 39 columns]

# %% [markdown]
# ### 6. Remove duplicates.
# - Check how many duplicates are in this dataset.
# - Drop the duplicates.
# - Confirm duplicates were removed.

# %%
# check number of duplicates
df = df.drop_duplicates()
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [message, original, genre, related, request, offer, aid_related, medical_help, medical_products, search_and_rescue, security, military, child_alone, water, food, shelter, clothing, money, missing_people, refugees, death, other_aid, infrastructure_related, transport, buildings, electricity, tools, hospitals, shops, aid_centers, other_infrastructure, weather_related, floods, storm, fire, earthquake, cold, other_weather, direct_report]
# Index: []
#
# [0 rows x 39 columns]

# %%
# drop duplicates

# %%
# check number of duplicates

# %% [markdown]
# ### 7. Save the clean dataset into an sqlite database.
# You can do this with pandas [`to_sql` method](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_sql.html) combined with the SQLAlchemy library. Remember to import SQLAlchemy's `create_engine` in the first cell of this notebook to use it below.

# %%
engine = create_engine('sqlite:///DisasterResponse.db')
df.to_sql("messages_df", engine, index=True, if_exists='replace')

# %% [markdown]
# ### 8. Use this notebook to complete `etl_pipeline.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database based on new datasets specified by the user. Alternatively, you can complete `etl_pipeline.py` in the classroom on the `Project Workspace IDE` coming later.
